# %%
import ml_module as ml
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt


file_path = 'customers.csv' 
data = ml.load_data(file_path)


target_column = 'Spending Score (1-100)'
X, y, preprocessor = ml.preprocess_data(data, target_column)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

model = ml.train_model(X_train, y_train)

y_pred = ml.predict(model, X_test)


mse, r2 = ml.evaluate_model(y_test, y_pred)
print(f"Среднеквадратичная ошибка: {mse:.2f}")
print(f"Коэффициент детерминации R^2: {r2:.2f}")

def plot_predictions(y_true, y_pred, num_points=50):
    plt.figure(figsize=(10, 6))
    plt.scatter(range(num_points), y_true[:num_points], color='blue', label='Истинные значения')
    plt.scatter(range(num_points), y_pred[:num_points], color='red', label='Предсказанные значения')
    plt.xlabel('Индекс')
    plt.ylabel('Значение Spending Score (1-100)')
    plt.title(f'Истинные и предсказанные значения Spending Score (1-100) (первые {num_points} точек)')
    plt.legend()
    plt.show()

plot_predictions(y_test, y_pred)
# Out:
# Успешно загружено 200 строк с 5 столбцами
# Столбцы: ['CustomerID', 'Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']
# Числовые признаки: ['CustomerID', 'Age', 'Annual Income (k$)']
# Категориальные признаки: ['Genre']
# Модель успешно обучена
# Среднеквадратичная ошибка: 562.92
# Коэффициент детерминации R^2: 0.06

# %%
gi
